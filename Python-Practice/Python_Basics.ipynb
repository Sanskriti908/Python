# %% [markdown]
# # Variables

# %%
name = 'Peter'
name
# Out:
# 'Peter'

# %%
n = 10
n
# Out:
# 10

# %%
b= True
b
# Out:
# True

# %%
## RULES FOR DEFINING VARIABLES

# 1. We cannont use any special character (Only underscore will work)
a^ = 21
a^

# %%
$a =14
$a
# Out:
#   Cell In[11], line 1
#     $a =14
#     ^
# SyntaxError: invalid syntax

# %%
_a = 18
_a
# Out:
# 18

# %%
_na_ = 'Victor'
_na_
# Out:
# 'Victor'

# %%
_na_m_e_='Victoria'
_na_m_e_
# Out:
# 'Victoria'

# %%
##2. Cannot use numbers at starting

1a =2
1a
# Out:
#   Cell In[15], line 3
#     1a =2
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 12
a1
# Out:
# 12

# %%
na1me = 'Gig'
na1me
# Out:
# 'Gig'

# %%
# na1me = 'Gig'
# na1me (ctrl A + Ctrl / for making the whole code as a comment in one go)

# %% [markdown]
# # DATA TYPES

# %%
# 1. INTEGER

n=10
n
# Out:
# 10

# %%
type(n)
# Out:
# int

# %%
type(100000000000000000000000000000000000)
# Out:
# int

# %%
# 2.FLOAT

f=10.11
f
# Out:
# 10.11

# %%
type(f)
# Out:
# float

# %%
# 3. STRINGS

name = 'John'
name1 = "Peter"
name2 = '''Victor'''
name
# Out:
# 'John'

# %%
name1
# Out:
# 'Peter'

# %%
name2
# Out:
# 'Victor'

# %%
# 4.Boolean

b = True
b1 = False
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
type(b)
# Out:
# bool

# %%
type(name1)
# Out:
# str

# %%
## 5. Null Type

nu = None
nu

# %%
type(nu)
# Out:
# NoneType

# %% [markdown]
# # TYPE CASTING ( Type Conversion)

# %%
# 1. Integer to Float

n = 10
n
# Out:
# 10

# %%
float(n)
# Out:
# 10.0

# %%
type(n)
# Out:
# int

# %%
# Reassign it

n = float(n)
n
# Out:
# 10.0

# %%
type(n)
# Out:
# float

# %%
# 2. Float to Integer

f = 10.11
f
# Out:
# 10.11

# %%
f = int(f)
f
# Out:
# 10

# %%
type(f)
# Out:
# int

# %%
# 3.String to float/integer and vice versa

name = 'John'
name
# Out:
# 'John'

# %%
type(name)
# Out:
# str

# %%
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 int(name)
#
# ValueError: invalid literal for int() with base 10: 'John'

# %%
float(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 float(name)
#
# ValueError: could not convert string to float: 'John'

# %%
name = '100'
name
# Out:
# '100'

# %%
int(name)
# Out:
# 100

# %%
float(name)
# Out:
# 100.0

# %%
type(name)
# Out:
# str

# %%
name = float(name)
name
# Out:
# 100.0

# %%
type (name)
# Out:
# float

# %%
# 4. Integer/Float to String

num = 10
num
# Out:
# 10

# %%
str(num)
# Out:
# '10'

# %%
f1 = 3.89
f1
# Out:
# 3.89

# %%
str(f1)
# Out:
# '3.89'

# %%
# 5. Integer/Float to Boolean

a = 13
a
# Out:
# 13

# %%
bool(a)
# Out:
# True

# %%
type(a)
# Out:
# int

# %%
a = 90.89
a
# Out:
# 90.89

# %%
bool(a)
# Out:
# True

# %%
a = 0 
a
# Out:
# 0

# %%
bool(a)
# Out:
# False

# %%
# 6. Boolean to Integer/Float

a = True
a
# Out:
# True

# %%
int(a)
# Out:
# 1

# %%
float(a)
# Out:
# 1.0

# %%
b = False
b
# Out:
# False

# %%
int(b)
# Out:
# 0

# %%
float(b)
# Out:
# 0.0

# %%
b2 = False
int(b2)
# Out:
# 0

# %% [markdown]
# # OPERATIONS

# %% [markdown]
# ## Arithmetic Operators

# %%
# 1. Addition

1+2+3+4+5
# Out:
# 15

# %%
1+2+3.0+4+5
# Out:
# 15.0

# %%
# 2. Substraction

10-1-2-3-4
# Out:
# 0

# %%
10-1-2.0-3-4
# Out:
# 0.0

# %%
# 3. Multiplication

10*2*4*5*6
# Out:
# 2400

# %%
10*2*4.0*5*6
# Out:
# 2400.0

# %%
# 4. Division

10/3
# Out:
# 3.3333333333333335

# %%
10.0/3
# Out:
# 3.3333333333333335

# %%
10.0/3.0
# Out:
# 3.3333333333333335

# %%
20/5
# Out:
# 4.0

# %%
# 5.Floor Division

10//3
# Out:
# 3

# %%
-10//3
# Out:
# -4

# %%
# 6.Modulus

10 % 3
# Out:
# 1

# %%
40 % 5
# Out:
# 0

# %%
# 7. Exponential/Power

2**2
# Out:
# 4

# %%
2**4
# Out:
# 16

# %%
4**6
# Out:
# 4096

# %% [markdown]
# ## Assignment Operators

# %%
# Equal to sign(=)
# eg: a = 7

# Double Assignment

a = 3
a= a+ 5
a
# Out:
# 8

# %%
a = 3
a+= 5
a
# Out:
# 8

# %%
x = 4
y = x+10
y
# Out:
# 14

# %%
x2 = 4
y2 += x2
y2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 x2 = 4
# ----> 2 y2 += x2
#       3 y2
#
# NameError: name 'y2' is not defined

# %%
x1 = 4
x1 += 10
x1
# Out:
# 14
