# %% [markdown]
# # String Functions

# %%
name = 'John'
len(name)
# Out:
# 4

# %%
name.lower()
# Out:
# 'john'

# %%
'John'.lower()
# Out:
# 'john'

# %%
name.upper()
# Out:
# 'JOHN'

# %%
name1 = '  john  '
len(name1)
# Out:
# 8

# %%
## title()
'the taj mahal'.title()
# Out:
# 'The Taj Mahal'

# %%
'The Taj Mahal'.title()
# Out:
# 'The Taj Mahal'

# %%
## capitalize()
'the taj mahal'.capitalize()
# Out:
# 'The taj mahal'

# %%
## split()
'Venu Gopal Iyer'.split()
# Out:
# ['Venu', 'Gopal', 'Iyer']

# %%
type('Venu Gopal Iyer'.split())
# Out:
# list

# %%
'a,b,c'.split(',')
# Out:
# ['a', 'b', 'c']

# %%
## Join
'-'.join(['apple','banana','cherry'])
# Out:
# 'apple-banana-cherry'

# %%
'-'.join('abc')
# Out:
# 'a-b-c'

# %%
'banana'.count('a')
# Out:
# 3

# %%
'banana'.count('an')
# Out:
# 2

# %%
' jo hn '.strip()
# Out:
# 'jo hn'

# %%
' jo hn '.lstrip()
# Out:
# 'jo hn '

# %%
' jo hn '.rstrip()
# Out:
# ' jo hn'

# %%
'banana'.find('a')
# Out:
# 1

# %%
'banana'.find('n')
# Out:
# 2

# %%
'john peter'.replace('peter','victor')
# Out:
# 'john victor'

# %%
'jo hn'.replace(' ','')
# Out:
# 'john'

# %%
## Escape Character
print('abc\n pqr')
# Out:
# abc
#  pqr

# %%
print('abc\npqr')
# Out:
# abc
# pqr

# %%
print('abc\tpqr')
# Out:
# abc	pqr

# %% [markdown]
#  ## LISTS

# %%
ls=['abc',1,10.3,True,None]
ls
# Out:
# ['abc', 1, 10.3, True, None]

# %%
ls=[] ##empty list
ls
# Out:
# []

# %%
ls=['apple','banana','cherry',['mango','grapes',[10,12,12,20]]]
ls
# Out:
# ['apple', 'banana', 'cherry', ['mango', 'grapes', [10, 12, 12, 20]]]

# %%
ls[3][1]
# Out:
# 'grapes'

# %%
ls[3][2][2]
# Out:
# 12

# %%
ls[-1][-1][2]
# Out:
# 12

# %% [markdown]
# ## LIST FUNCTIONS

# %%
#Additon

#a. Append()
pets=['cat','dog','hen']
pets
# Out:
# ['cat', 'dog', 'hen']

# %%
pets.append('horse')

# %%
pets
# Out:
# ['cat', 'dog', 'hen', 'horse']

# %%
pets.append([12,13])

# %%
pets
# Out:
# ['cat', 'dog', 'hen', 'horse', [12, 13]]

# %%
pets[-1]
# Out:
# [12, 13]

# %%
# b. extend()
pets.extend('deer')

# %%
pets
# Out:
# ['cat', 'dog', 'hen', 'horse', [12, 13], 'd', 'e', 'e', 'r']

# %%
pets.extend([23,45,12])
pets
# Out:
# ['cat', 'dog', 'hen', 'horse', [12, 13], 'd', 'e', 'e', 'r', 23, 45, 12]

# %%
pets.extend(['tiger',43,True])
pets
# Out:
# ['cat',
#  'dog',
#  'hen',
#  'horse',
#  [12, 13],
#  'd',
#  'e',
#  'e',
#  'r',
#  23,
#  45,
#  12,
#  'tiger',
#  43,
#  True]

# %%
# c. insert()
pets.insert(3,'deer')

# %%
pets
# Out:
# ['cat',
#  'dog',
#  'hen',
#  'deer',
#  'horse',
#  [12, 13],
#  'd',
#  'e',
#  'e',
#  'r',
#  23,
#  45,
#  12,
#  'tiger',
#  43,
#  True]

# %%
# 2. Remove
# a. pop()  ( output reflect bhi karata hai aur store bhi krta hai)
pets.pop()
# Out:
# True

# %%
pets
# Out:
# ['cat',
#  'dog',
#  'hen',
#  'deer',
#  'horse',
#  [12, 13],
#  'd',
#  'e',
#  'e',
#  'r',
#  23,
#  45,
#  12,
#  'tiger',
#  43]

# %%
pets.pop(6)
# Out:
# 'd'

# %%
pets
# Out:
# ['cat',
#  'dog',
#  'hen',
#  'deer',
#  'horse',
#  [12, 13],
#  'e',
#  'e',
#  'r',
#  23,
#  45,
#  12,
#  'tiger',
#  43]

# %%
# b. remove()
pets.remove('e') # will remove the first occurence of 'e'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 # b. remove()
# ----> 2 pets.remove('e')
#
# ValueError: list.remove(x): x not in list

# %%
# c. clear()
pets.clear()

# %%
pets
# Out:
# []

# %%
## 3. sort and filter

# sort

ls4=[12,4,89,5,23,78]
ls4
# Out:
# [12, 4, 89, 5, 23, 78]

# %%
ls4.sort()

# %%
ls4
# Out:
# [4, 5, 12, 23, 78, 89]

# %%
ls4.sort(reverse=True) (#descending)

# %%
ls4
# Out:
# [89, 78, 23, 12, 5, 4]

# %%
# reverse
ls5=[7,6,4,90]
ls5.reverse()

# %%
ls5
# Out:
# [90, 4, 6, 7]

# %%
ls5.sort()

# %%
ls5
# Out:
# [4, 6, 7, 90]

# %%
# c. count() ek argument dena zaruri hai otherwise error aayegi
ls9 = [5,67,34,8,34]
ls9
# Out:
# [5, 67, 34, 8, 34]

# %%
ls9.count(34)
# Out:
# 2

# %%
ls9.count(5)
# Out:
# 1

# %%
ls9.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 ls9.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
ls10=['a','a','b']
ls10
# Out:
# ['a', 'a', 'b']

# %%
ls10.count('a')
# Out:
# 2
